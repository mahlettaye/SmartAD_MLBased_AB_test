# %% [markdown]
# ### Data Exploaration on smart Ad Experimental data

# %%
import sys 
sys.path.insert(0, '/home/mahlet/10ac/Smart_Ad_AB_test/scripts/')

# %%
#importing necessary libraries 

from helper import *
import numpy as np
from sklearn import preprocessing

from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Ad_data= data_loader("/home/mahlet/10ac/Smart_Ad_AB_test/data/AdSmartABdata.csv")
# Out:
# 2021-08-16 06:29:27,402:ERROR:You have entered correct path
# NoneType: None

# %%
data_summary(Ad_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8077 entries, 0 to 8076
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   auction_id   8077 non-null   object
#  1   experiment   8077 non-null   object
#  2   date         8077 non-null   object
#  3   hour         8077 non-null   int64
#  4   device_make  8077 non-null   object
#  5   platform_os  8077 non-null   int64
#  6   browser      8077 non-null   object
#  7   yes          8077 non-null   int64
#  8   no           8077 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 568.0+ KB
# Information about columns None
# Your data shape is: (8077, 9)
# Your data row count is 72693
# The number of missing value(s): 0
# Columons having columns value:Index([], dtype='object')

# %% [markdown]
# ### Univariate analyisis

# %%
#unique value count for each Auction Identifier 
Unique_auction_id= Ad_data['auction_id'].nunique()
print("Unique user identifier",Unique_auction_id)
# Out:
# Unique user identifier 8077

# %%
sns.set_theme(style="darkgrid")
ax = plt.axes()
sns.countplot(data=Ad_data,x='experiment',palette="rocket")
ax.set_title("Experiment information")

plt.show()

# %%
plt.figure(figsize=(10,8))
ax = plt.axes()
sns.countplot(data=Ad_data,y='date',palette="rocket")
ax.set_title("Date count information ")

plt.show()

# %%
plt.figure(figsize=(10,8))
ax = plt.axes()
sns.countplot(data=Ad_data,y='hour',palette="rocket")
ax.set_title("Hours count information")

plt.show()

# %%
plt.figure(figsize=(10,8))
ax = plt.axes()
sns.countplot(data=Ad_data,y='platform_os',order=Ad_data['platform_os'].value_counts().iloc[:5].index,palette="rocket")
ax.set_title("paltform_os count information")

plt.show()

# %%
plt.figure(figsize=(10,8))
ax = plt.axes()
sns.countplot(data=Ad_data,y='browser',order=Ad_data['browser'].value_counts().iloc[:10].index,palette="rocket",edgecolor=(0,0,0))
ax.set_title("paltform_os count information")

plt.show()

# %% [markdown]
# Bivariate Analyisis

# %%
plt.figure(figsize=(10,8))
ax = plt.axes()
sns.countplot(data=Ad_data,x='experiment',hue='yes',palette="rocket",edgecolor=(0,0,0))
ax.set_title("Experiment and yes count information")
# Out:
# Text(0.5, 1.0, 'Experiment and yes count information')

# %%
plt.figure(figsize=(10,8))
ax = plt.axes()
sns.countplot(data=Ad_data,x='experiment',hue='no',palette="rocket",edgecolor=(0,0,0))
ax.set_title("Experiment and no count information")
# Out:
# Text(0.5, 1.0, 'Experiment and no count information')

# %%
plt.figure(figsize=(10,8))
ax = plt.axes()
sns.countplot(data=Ad_data,x='date',hue='experiment',palette="rocket",edgecolor=(0,0,0))
ax.set_title("Experiment and yes count information")
# Out:
# Text(0.5, 1.0, 'Experiment and yes count information')

# %%
#variables corelation 
variables_correlation= Ad_data.corr()
ax = plt.axes()
sns.heatmap(variables_correlation, vmin=0, vmax=0.5, annot=True)
ax.set_title("Correlation between variables")
# Out:
# Text(0.5, 1.0, 'Correlation between variables')

# %% [markdown]
# The correlation matics shows as there is no significat correlation between variables in the given dataset.

# %%
# Filtering data to extract features and lables
awarness_inx=((Ad_data['yes']==1) | (Ad_data['no']==1))
awarness_df=Ad_data[awarness_inx].copy()
awarness_df.reset_index(drop=True, inplace=True)
awarness_df= awarness_df[awarness_df.columns[:-1]].copy()
awarness_df.rename(columns={'yes':'awarness'}, inplace=True)
awarness_df.head()
# Out:
#                              auction_id experiment        date  hour  \
# 0  0016d14a-ae18-4a02-a204-6ba53b52f2ed    exposed  2020-07-05     2
# 1  008aafdf-deef-4482-8fec-d98e3da054da    exposed  2020-07-04    16
# 2  00a1384a-5118-4d1b-925b-6cdada50318d    exposed  2020-07-06     8
# 3  00b6fadb-10bd-49e3-a778-290da82f7a8d    control  2020-07-08     4
# 4  00ebf4a8-060f-4b99-93ac-c62724399483    control  2020-07-03    15
#
#           device_make  platform_os                browser  awarness
# 0               E5823            6  Chrome Mobile WebView         0
# 1  Generic Smartphone            6          Chrome Mobile         1
# 2  Generic Smartphone            6          Chrome Mobile         0
# 3    Samsung SM-A202F            6               Facebook         1
# 4  Generic Smartphone            6          Chrome Mobile         0

# %%
#dropping colums which are not imformative less relevant to our analyisis
del awarness_df['auction_id']
awarness_df['date']=pd.to_datetime(awarness_df['date'])
awarness_df['day']=awarness_df['date'].dt.day_name()
del awarness_df['date']
awarness_df.head()
# Out:
#   experiment  hour         device_make  platform_os                browser  \
# 0    exposed     2               E5823            6  Chrome Mobile WebView
# 1    exposed    16  Generic Smartphone            6          Chrome Mobile
# 2    exposed     8  Generic Smartphone            6          Chrome Mobile
# 3    control     4    Samsung SM-A202F            6               Facebook
# 4    control    15  Generic Smartphone            6          Chrome Mobile
#
#    awarness        day
# 0         0     Sunday
# 1         1   Saturday
# 2         0     Monday
# 3         1  Wednesday
# 4         0     Friday

# %%
encoder = preprocessing.LabelEncoder()
awarness_df['experiment']=encoder.fit_transform(awarness_df['experiment'])
awarness_df['device_make']=encoder.fit_transform(awarness_df['device_make'])
awarness_df['browser']=encoder.fit_transform(awarness_df['browser'])
awarness_df['day']=encoder.fit_transform(awarness_df['day'])
awarness_df.head()
# Out:
#    experiment  hour  device_make  platform_os  browser  awarness  day
# 0           1     2            4            6        2         0    3
# 1           1    16           13            6        1         1    2
# 2           1     8           13            6        1         0    1
# 3           0     4           43            6        4         1    6
# 4           0    15           13            6        1         0    0

# %%
#variables corelation 
awarness_correlation= awarness_df.corr()
ax = plt.axes()
sns.heatmap(awarness_correlation, vmin=0, vmax=0.5, annot=True)
ax.set_title("Correlation between variables")
# Out:
# Text(0.5, 1.0, 'Correlation between variables')

# %% [markdown]
# From this correlation map variables browser and device make are highly correlated we can drop either of them.

# %%
del awarness_df['device_make']
awarness_df.head()
# Out:
#    experiment  hour  platform_os  browser  awarness  day
# 0           1     2            6        2         0    3
# 1           1    16            6        1         1    2
# 2           1     8            6        1         0    1
# 3           0     4            6        4         1    6
# 4           0    15            6        1         0    0

# %%
scaler = MinMaxScaler()
scaled_data=pd.DataFrame(scaler.fit_transform(awarness_df),columns=('experiment','hour','platform_os','browser','awarness','day'))
print(scaled_data)
# Out:
#       experiment      hour  platform_os   browser  awarness       day
# 0            1.0  0.086957          1.0  0.285714       0.0  0.500000
# 1            1.0  0.695652          1.0  0.142857       1.0  0.333333
# 2            1.0  0.347826          1.0  0.142857       0.0  0.166667
# 3            0.0  0.173913          1.0  0.571429       1.0  1.000000
# 4            0.0  0.652174          1.0  0.142857       0.0  0.000000
# ...          ...       ...          ...       ...       ...       ...
# 1238         1.0  0.913043          1.0  0.142857       1.0  0.500000
# 1239         1.0  0.043478          1.0  0.142857       1.0  0.333333
# 1240         0.0  0.304348          1.0  0.142857       0.0  0.666667
# 1241         0.0  0.695652          1.0  0.142857       0.0  0.000000
# 1242         1.0  0.173913          1.0  0.142857       0.0  0.000000
#
# [1243 rows x 6 columns]

# %%
#writing the preprocessed data to csv file
scaled_data.to_csv("/home/mahlet/10ac/Smart_Ad_AB_test/data/processed_data.csv")
